# %%
# Load foldseek clustering results

import pandas as pd

cluster_combined = '/home/ubuntu/CIRPIN/cpdb_comparison/foldseek_CPDB_comparison/cpdb_pdbs_2/conA_pdbs/conA_pdbs/cdhit_cluster.tsv'
cluster_combined = '/home/ubuntu/CIRPIN/cpdb_comparison/foldseek_CPDB_comparison/cpdb_pdbs_2/conA_pdbs/conA_pdbs/cdhit_clustermode2_tm05_c09_covmode2_align1conA_cluster.tsv'


cluster_combined = '/home/ubuntu/CIRPIN/cpdb_comparison/foldseek_CPDB_comparison/CIRPIN_pdbs/AFDB_scope40/cdhit_clustermode2_tm05_c09_covmode2_align1_afdb_scope_cluster.tsv'





### SCOPE40 CIRPIN PDB clusters
cluster_combined = '/home/ubuntu/CIRPIN/cpdb_comparison/foldseek_CPDB_comparison/CIRPIN_pdbs/scope40_only/cdhit_clustermode2_tm05_c09_covmode2_align1_scope40_cluster.tsv'

### ENTIRE SCOPE40  clusters

cluster_combined = '/home/ubuntu/scope40/foldseek_clustering/cdhit_clustermode2_tm05_c09_covmode2_align1_scope40_whole_cluster.tsv'

### AFDB no CATH CIRPIN clusters
cluster_combined = '/home/ubuntu/CIRPIN/cpdb_comparison/foldseek_CPDB_comparison/CIRPIN_pdbs/AFDB_no_CATH/cdhit_clustermode2_tm05_c09_covmode2_align1_noCATH_cluster.tsv'

## CPDB

cluster_combined= '/home/ubuntu/CIRPIN/cpdb_comparison/foldseek_CPDB_comparison/cpdb_pdbs_2/cpdb_pdbs_copied/cdhit_clustermode2_tm05_c09_covmode2_align1_CPDB_cluster.tsv'


### AFDB only CIRPIN hits (20138)

cluster_combined= '/home/ubuntu/CIRPIN/cpdb_comparison/foldseek_CPDB_comparison/CIRPIN_pdbs/AFDB_only/cdhit_clustermode2_tm05_c09_covmode2_align1_afdb_only_cluster.tsv'
fs_cluster_combined = pd.read_csv(cluster_combined, sep='\t', header =None)


fs_cluster_combined.columns = ['Cluster','Structure']

cluster_combined_dict = (
    fs_cluster_combined.groupby('Cluster')['Structure']
      .apply(list)
      .to_dict()
)


# Get number of Foldseek clusters before accounting for CP

print(f'Combined Foldseek clusters: {len(cluster_combined_dict)}')
# Out:
# Combined Foldseek clusters: 1499

# %%
[k for k, v in cluster_combined_dict.items() if "d2vsva1" in v]
# Out:
# ['d5m3na2']

# %%
cluster_combined_dict['d5m3na2']
# Out:
# ['d5m3na2',
#  'd3stja2',
#  'd2p3wa1',
#  'd1p1da2',
#  'd1uf1a1',
#  'd2daza1',
#  'd2o2ta1',
#  'd1um1a1',
#  'd3nfka_',
#  'd1mfga1',
#  'd6x1ra1',
#  'd1kwaa_',
#  'd2q9va1',
#  'd3vqfa_',
#  'd4uu5a1',
#  'd6y38a_',
#  'd3axaa_',
#  'd1fc6a3',
#  'd3khfa1',
#  'd2egoa1',
#  'd4n6xa1',
#  'd2iwoa_',
#  'd3b76a1',
#  'd4q2qa_',
#  'd2f5ya1',
#  'd2vsva1',
#  'd1wi2a1',
#  'd2eeha1',
#  'd2dlua1',
#  'd1n7ea_',
#  'd1ihja_',
#  'd2h2ba1',
#  'd2w4fa1',
#  'd1m5za_']
